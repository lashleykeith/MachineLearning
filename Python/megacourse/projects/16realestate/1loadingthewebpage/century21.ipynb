# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get("http://www.century21.com/real-estate/detroit-mi/LCMIDETROIT/")
c = r.content
# Out:
# b'\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="en" data-usagetrack-config=\'{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}\'>\r\n<head>\r\n   <meta charset="utf-8">\r\n   <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n   <meta content="yes" name="apple-mobile-web-app-capable">\r\n   <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport">\r\n   <meta name="p:domain_verify" content="4c07bdfa5bc2a138becfc315e369d957">\r\n   <meta name="title" content="Detroit Real Estate | Find Houses & Homes for Sale in Detroit, MI">\r\n   <meta name="description" content="Search Detroit real estate property listings to find homes for sale in Detroit, MI. Browse houses for sale in Detroit today!"/>\r\n   <meta name="keywords" content="Detroit real estate, Detroit homes, Detroit homes for sale, Detroit properties, Detroit listings, Detroit houses for sale, MI real estate, MI homes, MI homes for sale, 
# ...

# %%
soup = BeautifulSoup(c,"html.parser")
# Out:
# <!DOCTYPE html>
# <html data-usagetrack-config='{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}' lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="4c07bdfa5bc2a138becfc315e369d957" name="p:domain_verify"/>
#   <meta content="Detroit Real Estate | Find Houses &amp; Homes for Sale in Detroit, MI" name="title"/>
#   <meta content="Search Detroit real estate property listings to find homes for sale in Detroit, MI. Browse houses for sale in Detroit today!" name="description">
# ...

# %%
all = soup.find_all("div",{"class":"property-card-image"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b19f36da58e6> in <module>()
# ----> 1 all = soup.find_all("div",{"class":"property-card-image"})
#
# NameError: name 'soup' is not defined
